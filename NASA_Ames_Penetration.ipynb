# %%
###### Transect 1 ###### 

# Current State #

#### intrusion parameters ####
# extrude speed: 1 cm/s #
# depth prescribed: 8 cm #

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#locate file
df1_1 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F1_Wed_May__8_12_02_16_2024.csv', header = 2))
df1_2 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F2_Wed_May__8_12_04_08_2024.csv', header = 2))
df1_3 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F3_Wed_May__8_12_07_00_2024.csv', header = 2))
df1_4 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F4_Wed_May__8_12_09_19_2024.csv', header = 2))
df1_5 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F5_Wed_May__8_12_10_27_2024.csv', header = 2))
df1_6 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F6_Wed_May__8_12_11_50_2024.csv', header = 2))
df1_7 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F7_Wed_May__8_12_13_27_2024.csv', header = 2))
df1_8 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F8_Wed_May__8_12_14_36_2024.csv', header = 2))
df1_9 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F9_Wed_May__8_12_17_02_2024.csv', header = 2))
df1_10 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F10_Wed_May__8_12_18_39_2024.csv', header = 2))
df1_11 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F11_Wed_May__8_12_20_10_2024.csv', header = 2))
df1_12 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F12_Wed_May__8_12_21_38_2024.csv', header = 2))
df1_13 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F13_Wed_May__8_12_22_51_2024.csv', header = 2))
df1_14 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F14_Wed_May__8_12_25_53_2024.csv', header = 2))
df1_15 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F15_Wed_May__8_12_29_43_2024.csv', header = 2))
df1_16 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F16_Wed_May__8_12_31_03_2024.csv', header = 2))
df1_17 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F17_Wed_May__8_12_33_19_2024.csv', header = 2))
df1_18 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F18_Wed_May__8_12_34_51_2024.csv', header = 2))
df1_19 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F19_Wed_May__8_12_36_14_2024.csv', header = 2))
df1_20 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T1/data/AMES24_LHS1_T1_P_F20_Wed_May__8_12_37_33_2024.csv', header = 2))

#extract depth and force values
df1_1_rawZ1 = df1_1[7550:10000,4] #10:16000 shows full profile, 7550:10000 is good
df1_1_rawFy1 = df1_1[7550:10000,2]

df1_2_rawZ1 = df1_2[6050:15000,4] 
df1_2_rawFy1 = df1_2[6050:15000,2]

df1_3_rawZ1 = df1_3[6100:15000,4] 
df1_3_rawFy1 = df1_3[6100:15000,2]

df1_4_rawZ1 = df1_4[5800:15000,4] 
df1_4_rawFy1 = df1_4[5800:15000,2]

df1_5_rawZ1 = df1_5[5800:15000,4] 
df1_5_rawFy1 = df1_5[5800:15000,2]

df1_6_rawZ1 = df1_6[5500:15000,4] 
df1_6_rawFy1 = df1_6[5500:15000,2]

df1_7_rawZ1 = df1_7[5700:15000,4] 
df1_7_rawFy1 = df1_7[5700:15000,2]

df1_8_rawZ1 = df1_8[5900:15000,4] 
df1_8_rawFy1 = df1_8[5900:15000,2]

df1_9_rawZ1 = df1_9[5300:14400,4] 
df1_9_rawFy1 = df1_9[5300:14400,2]

df1_10_rawZ1 = df1_10[5800:15000,4] 
df1_10_rawFy1 = df1_10[5800:15000,2]

df1_11_rawZ1 = df1_11[5600:14500,4] 
df1_11_rawFy1 = df1_11[5600:14500,2]

df1_12_rawZ1 = df1_12[5800:15000,4] 
df1_12_rawFy1 = df1_12[5800:15000,2]

df1_13_rawZ1 = df1_13[5150:14000,4] 
df1_13_rawFy1 = df1_13[5150:14000,2]

df1_14_rawZ1 = df1_14[5150:14000,4] 
df1_14_rawFy1 = df1_14[5150:14000,2]

df1_15_rawZ1 = df1_15[5250:14000,4] 
df1_15_rawFy1 = df1_15[5250:14000,2]

df1_16_rawZ1 = df1_16[5150:13800,4] 
df1_16_rawFy1 = df1_16[5150:13800,2]

df1_17_rawZ1 = df1_17[6400:13800,4] 
df1_17_rawFy1 = df1_17[6400:13800,2]

df1_18_rawZ1 = df1_18[6200:13800,4] 
df1_18_rawFy1 = df1_18[6200:13800,2]

df1_19_rawZ1 = df1_19[6250:14000,4] 
df1_19_rawFy1 = df1_19[6250:14000,2]

df1_20_rawZ1 = df1_20[6250:13800,4] 
df1_20_rawFy1 = df1_20[6250:13800,2]

#plotting
#plt.plot(-df1_1_rawZ1-0.245, -df1_1_rawFy1) #this one could be faulty, look at the other ones to see (little short in depth)

plt.plot(-df1_2_rawZ1-0.2235, -df1_2_rawFy1)
plt.plot(-df1_3_rawZ1-0.213, -df1_3_rawFy1)
plt.plot(-df1_4_rawZ1-0.203, -df1_4_rawFy1)
plt.plot(-df1_5_rawZ1-0.203, -df1_5_rawFy1)
plt.plot(-df1_6_rawZ1-0.1985, -df1_6_rawFy1)
plt.plot(-df1_7_rawZ1-0.193, -df1_7_rawFy1)
plt.plot(-df1_8_rawZ1-0.195, -df1_8_rawFy1)
plt.plot(-df1_9_rawZ1-0.189, -df1_9_rawFy1)
plt.plot(-df1_10_rawZ1-0.20, -df1_10_rawFy1)
plt.plot(-df1_11_rawZ1-0.193, -df1_11_rawFy1)
plt.plot(-df1_12_rawZ1-0.196, -df1_12_rawFy1)
plt.plot(-df1_13_rawZ1-0.187, -df1_13_rawFy1)
plt.plot(-df1_14_rawZ1-0.189, -df1_14_rawFy1)
plt.plot(-df1_15_rawZ1-0.1885, -df1_15_rawFy1)
plt.plot(-df1_16_rawZ1-0.189, -df1_16_rawFy1)
plt.plot(-df1_17_rawZ1-0.204, -df1_17_rawFy1)
plt.plot(-df1_18_rawZ1-0.205, -df1_18_rawFy1)
plt.plot(-df1_19_rawZ1-0.198, -df1_19_rawFy1)
plt.plot(-df1_20_rawZ1-0.203, -df1_20_rawFy1)

plt.xlabel('z (m)', size = 'x-large')
plt.ylabel(r'$F_{z}$ (N)', size = 'x-large')
plt.title("Transect 1 - Current State")
plt.show()

#finding an average
#T2_Z_arr_055 = np.array([[df1_055_rawZ1], [df2_055_rawZ2], [df3_055_rawZ3], [df4_055_rawZ4], [df5_055_rawZ5]])
#T2_Z_avg_arr_055 = np.mean(T2_Z_arr_055, axis = 0)

#T2_Fy_arr_055 = np.array([[df1_055_rawFy1], [df2_055_rawFy2], [df3_055_rawFy3], [df4_055_rawFy4], [df5_055_rawFy5]])
#T2_Fy_avg_arr_055 = np.mean(T2_Fy_arr_055, axis = 0)

#plotting
#plt.scatter(-T2_Z_avg_arr_055-0.175, T2_Fy_avg_arr_055, s = 1)
#plt.xlabel('z (m)', size = 'x-large')
#plt.ylabel(r'$F_{y}$ (N)', size = 'x-large')
#plt.title('V 0.55 avg')
#plt.show()

# %%
###### Transect 2 ######

# RLP #

#### intrusion parameters ####
# extrude speed: 1 cm/s #
# depth prescribed: 8 cm #

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#locate file
df2_1 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F1_Wed_May__8_12_48_43_2024.csv', header = 2))
df2_2 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F2_Wed_May__8_12_51_52_2024.csv', header = 2))
df2_3 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F3_Wed_May__8_12_52_45_2024.csv', header = 2))
df2_4 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F4_Wed_May__8_12_53_48_2024.csv', header = 2))
df2_5 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F5_Wed_May__8_12_54_48_2024.csv', header = 2))
df2_6 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F6_Wed_May__8_12_55_46_2024.csv', header = 2))
df2_7 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F7_Wed_May__8_12_56_59_2024.csv', header = 2))
df2_8 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F8_Wed_May__8_12_57_54_2024.csv', header = 2))
df2_9 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F9_Wed_May__8_12_59_40_2024.csv', header = 2))
df2_10 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F10_Wed_May__8_13_00_37_2024.csv', header = 2))
df2_11 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F11_Wed_May__8_13_01_42_2024.csv', header = 2))
df2_12 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F12_Wed_May__8_13_02_39_2024.csv', header = 2))
df2_13 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F13_Wed_May__8_13_03_46_2024.csv', header = 2))
df2_14 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F14_Wed_May__8_13_05_38_2024.csv', header = 2))
df2_15 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F15_Wed_May__8_13_06_48_2024.csv', header = 2))
df2_16 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F16_Wed_May__8_13_07_41_2024.csv', header = 2))
df2_17 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F17_Wed_May__8_13_08_34_2024.csv', header = 2))
df2_18 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F18_Wed_May__8_13_09_42_2024.csv', header = 2))
df2_19 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F19_Wed_May__8_13_10_42_2024.csv', header = 2))
df2_20 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T2/data/AMES24_LHS1_T2_P_F20_Wed_May__8_13_11_52_2024.csv', header = 2))

#extract depth and force values
df2_1_rawZ1 = df2_1[5600:13000,4]
df2_1_rawFy1 = df2_1[5600:13000,2]

df2_2_rawZ1 = df2_2[5600:13000,4] 
df2_2_rawFy1 = df2_2[5600:13000,2]

df2_3_rawZ1 = df2_3[6900:13000,4] 
df2_3_rawFy1 = df2_3[6900:13000,2]

df2_4_rawZ1 = df2_4[6700:13000,4] 
df2_4_rawFy1 = df2_4[6700:13000,2]

df2_5_rawZ1 = df2_5[6500:15000,4] 
df2_5_rawFy1 = df2_5[6500:15000,2]

df2_6_rawZ1 = df2_6[7000:15000,4] 
df2_6_rawFy1 = df2_6[7000:15000,2]

df2_7_rawZ1 = df2_7[6700:15000,4] 
df2_7_rawFy1 = df2_7[6700:15000,2]

df2_8_rawZ1 = df2_8[6400:14000,4] 
df2_8_rawFy1 = df2_8[6400:14000,2]

df2_9_rawZ1 = df2_9[6500:14400,4] 
df2_9_rawFy1 = df2_9[6500:14400,2]

df2_10_rawZ1 = df2_10[6800:15000,4] 
df2_10_rawFy1 = df2_10[6800:15000,2]

df2_11_rawZ1 = df2_11[6400:14500,4] 
df2_11_rawFy1 = df2_11[6400:14500,2]

df2_12_rawZ1 = df2_12[6400:15000,4] 
df2_12_rawFy1 = df2_12[6400:15000,2]

df2_13_rawZ1 = df2_13[6400:14000,4] 
df2_13_rawFy1 = df2_13[6400:14000,2]

df2_14_rawZ1 = df2_14[6400:14000,4] 
df2_14_rawFy1 = df2_14[6400:14000,2]

df2_15_rawZ1 = df2_15[6400:14000,4] 
df2_15_rawFy1 = df2_15[6400:14000,2]

df2_16_rawZ1 = df2_16[6400:13800,4] 
df2_16_rawFy1 = df2_16[6400:13800,2]

df2_17_rawZ1 = df2_17[6400:13800,4] 
df2_17_rawFy1 = df2_17[6400:13800,2]

df2_18_rawZ1 = df2_18[6400:13800,4] 
df2_18_rawFy1 = df2_18[6400:13800,2]

df2_19_rawZ1 = df2_19[6400:14000,4] 
df2_19_rawFy1 = df2_19[6400:14000,2]

df2_20_rawZ1 = df2_20[6400:13800,4] 
df2_20_rawFy1 = df2_20[6400:13800,2]

#plotting
plt.plot(-df2_1_rawZ1-0.193, -df2_1_rawFy1)
plt.plot(-df2_2_rawZ1-0.194, -df2_2_rawFy1)
plt.plot(-df2_3_rawZ1-0.207, -df2_3_rawFy1)
plt.plot(-df2_4_rawZ1-0.203, -df2_4_rawFy1)
plt.plot(-df2_5_rawZ1-0.214, -df2_5_rawFy1) #good
plt.plot(-df2_6_rawZ1-0.207, -df2_6_rawFy1)
plt.plot(-df2_7_rawZ1-0.216, -df2_7_rawFy1)
plt.plot(-df2_8_rawZ1-0.20, -df2_8_rawFy1)
plt.plot(-df2_9_rawZ1-0.215, -df2_9_rawFy1)
plt.plot(-df2_10_rawZ1-0.211, -df2_10_rawFy1)
plt.plot(-df2_11_rawZ1-0.206, -df2_11_rawFy1) #good 
plt.plot(-df2_12_rawZ1-0.226, -df2_12_rawFy1)
plt.plot(-df2_13_rawZ1-0.202, -df2_13_rawFy1)
plt.plot(-df2_14_rawZ1-0.209, -df2_14_rawFy1)
plt.plot(-df2_15_rawZ1-0.21, -df2_15_rawFy1)
plt.plot(-df2_16_rawZ1-0.20, -df2_16_rawFy1)
plt.plot(-df2_17_rawZ1-0.209, -df2_17_rawFy1)
plt.plot(-df2_18_rawZ1-0.205, -df2_18_rawFy1)
plt.plot(-df2_19_rawZ1-0.213, -df2_19_rawFy1) #good
plt.plot(-df2_20_rawZ1-0.209, -df2_20_rawFy1)

plt.xlabel('z (m)', size = 'x-large')
plt.ylabel(r'$F_{z}$ (N)', size = 'x-large')
plt.title("Transect 2 - RLP")
plt.show()

# %%
###### Transect 3 ######

# RCP #

#### intrusion parameters ####
# extrude speed: 1 cm/s #
# depth prescribed: 8 cm #

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#locate file
df3_1 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F1_Thu_May__9_11_59_29_2024.csv', header = 2))
df3_2 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F2_Thu_May__9_12_10_31_2024.csv', header = 2))
df3_3 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F3_Thu_May__9_12_12_00_2024.csv', header = 2))
df3_4 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F4_Thu_May__9_12_12_54_2024.csv', header = 2))
df3_5 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F5_Thu_May__9_12_13_59_2024.csv', header = 2))
df3_6 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F6_Thu_May__9_12_15_31_2024.csv', header = 2))
df3_7 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F7_Thu_May__9_12_16_36_2024.csv', header = 2))
df3_8 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F8_Thu_May__9_12_17_47_2024.csv', header = 2))
df3_9 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F9_Thu_May__9_12_19_42_2024.csv', header = 2))
df3_10 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F10_Thu_May__9_12_20_40_2024.csv', header = 2))
df3_11 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F11_Thu_May__9_12_22_15_2024.csv', header = 2))
df3_12 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F12_Thu_May__9_12_24_57_2024.csv', header = 2))
df3_13 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F13_Thu_May__9_12_26_22_2024.csv', header = 2))
df3_14 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F14_Thu_May__9_12_27_48_2024.csv', header = 2))
df3_15 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F15_Thu_May__9_12_28_44_2024.csv', header = 2))
df3_16 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F16_Thu_May__9_12_31_12_2024.csv', header = 2))
df3_17 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F17_Thu_May__9_12_32_17_2024.csv', header = 2))
df3_18 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F18_Thu_May__9_12_33_33_2024.csv', header = 2))
df3_19 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F19_Thu_May__9_12_35_44_2024.csv', header = 2))
df3_20 = np.asarray(pd.read_csv('LabData/NASA_Ames_LHS1_Penetration/T3/data/AMES24_LHS1_T3_P_F20_Thu_May__9_12_36_55_2024.csv', header = 2))

#extract depth and force values
df3_1_rawZ1 = df3_1[5600:10500,4]
df3_1_rawFy1 = df3_1[5600:10500,2]

df3_2_rawZ1 = df3_2[6000:13000,4] 
df3_2_rawFy1 = df3_2[6000:13000,2]

df3_3_rawZ1 = df3_3[5800:13000,4] 
df3_3_rawFy1 = df3_3[5800:13000,2]

df3_4_rawZ1 = df3_4[6000:13000,4] 
df3_4_rawFy1 = df3_4[6000:13000,2]

df3_5_rawZ1 = df3_5[5700:13000,4] 
df3_5_rawFy1 = df3_5[5700:13000,2]

df3_6_rawZ1 = df3_6[5900:13000,4] 
df3_6_rawFy1 = df3_6[5900:13000,2]

df3_7_rawZ1 = df3_7[5700:13000,4] 
df3_7_rawFy1 = df3_7[5700:13000,2]

df3_8_rawZ1 = df3_8[6000:13000,4] 
df3_8_rawFy1 = df3_8[6000:13000,2]

df3_9_rawZ1 = df3_9[5700:13000,4] 
df3_9_rawFy1 = df3_9[5700:13000,2]

df3_10_rawZ1 = df3_10[5750:13000,4] 
df3_10_rawFy1 = df3_10[5750:13000,2]

df3_11_rawZ1 = df3_11[5900:13000,4] 
df3_11_rawFy1 = df3_11[5900:13000,2]

df3_12_rawZ1 = df3_12[5600:12000,4] 
df3_12_rawFy1 = df3_12[5600:12000,2]

df3_13_rawZ1 = df3_13[5800:13000,4] 
df3_13_rawFy1 = df3_13[5800:13000,2]

df3_14_rawZ1 = df3_14[5800:13000,4] 
df3_14_rawFy1 = df3_14[5800:13000,2]

df3_15_rawZ1 = df3_15[5500:14000,4] 
df3_15_rawFy1 = df3_15[5500:14000,2]

df3_16_rawZ1 = df3_16[5500:14000,4] 
df3_16_rawFy1 = df3_16[5500:14000,2]

df3_17_rawZ1 = df3_17[5700:14000,4] 
df3_17_rawFy1 = df3_17[5700:14000,2]

df3_18_rawZ1 = df3_18[5500:14000,4] 
df3_18_rawFy1 = df3_18[5500:14000,2]

df3_19_rawZ1 = df3_19[5600:14000,4] 
df3_19_rawFy1 = df3_19[5600:14000,2]

df3_20_rawZ1 = df3_20[5700:14000,4] 
df3_20_rawFy1 = df3_20[5700:14000,2]

#plotting
plt.plot(-df3_1_rawZ1-0.193, -df3_1_rawFy1)
plt.plot(-df3_2_rawZ1-0.196, -df3_2_rawFy1)
plt.plot(-df3_3_rawZ1-0.195, -df3_3_rawFy1)
plt.plot(-df3_4_rawZ1-0.207, -df3_4_rawFy1)
plt.plot(-df3_5_rawZ1-0.201, -df3_5_rawFy1)
plt.plot(-df3_6_rawZ1-0.198, -df3_6_rawFy1)
plt.plot(-df3_7_rawZ1-0.192, -df3_7_rawFy1)
plt.plot(-df3_8_rawZ1-0.207, -df3_8_rawFy1)
plt.plot(-df3_9_rawZ1-0.205, -df3_9_rawFy1)
plt.plot(-df3_10_rawZ1-0.2025, -df3_10_rawFy1)
plt.plot(-df3_11_rawZ1-0.2065, -df3_11_rawFy1) 
plt.plot(-df3_12_rawZ1-0.2125, -df3_12_rawFy1)
plt.plot(-df3_13_rawZ1-0.212, -df3_13_rawFy1)
plt.plot(-df3_14_rawZ1-0, -df3_14_rawFy1) #something weird going on here 
plt.plot(-df3_15_rawZ1-0.19, -df3_15_rawFy1)
plt.plot(-df3_16_rawZ1-0.199, -df3_16_rawFy1)
plt.plot(-df3_17_rawZ1-0.2065, -df3_17_rawFy1)
plt.plot(-df3_18_rawZ1-0.1915, -df3_18_rawFy1)
plt.plot(-df3_19_rawZ1-0.20, -df3_19_rawFy1)
plt.plot(-df3_20_rawZ1-0.20, -df3_20_rawFy1)

plt.xlabel('z (m)', size = 'x-large')
plt.ylabel(r'$F_{z}$ (N)', size = 'x-large')
plt.title("Transect 3 - RCP")
plt.show()

# %%
##### Transects 2 & 3 Aggregate #####

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams.update({
    'text.color': 'white',
    'axes.edgecolor': 'white',
    'axes.labelcolor': 'white',
    'xtick.color': 'white',
    'ytick.color': 'white',
    'figure.facecolor': 'black',
    'axes.facecolor': 'black',
    'savefig.facecolor': 'black',
    'legend.facecolor': 'black',
    'legend.edgecolor': 'white'
})

## and T1, but obviously these trends are much more variable

#### T1 ####
#plt.plot(-df1_2_rawZ1-0.2235, -df1_2_rawFy1, color = 'red')
#plt.plot(-df1_3_rawZ1-0.213, -df1_3_rawFy1, color = 'red')
#plt.plot(-df1_4_rawZ1-0.203, -df1_4_rawFy1, color = 'red')
#plt.plot(-df1_5_rawZ1-0.203, -df1_5_rawFy1, color = 'red')
#plt.plot(-df1_6_rawZ1-0.1985, -df1_6_rawFy1, color = 'red')
#plt.plot(-df1_7_rawZ1-0.193, -df1_7_rawFy1, color = 'red')
#plt.plot(-df1_8_rawZ1-0.195, -df1_8_rawFy1, color = 'red')
#plt.plot(-df1_9_rawZ1-0.189, -df1_9_rawFy1, color = 'red')
#plt.plot(-df1_10_rawZ1-0.20, -df1_10_rawFy1, color = 'red')
#plt.plot(-df1_11_rawZ1-0.193, -df1_11_rawFy1, color = 'red')
#plt.plot(-df1_12_rawZ1-0.196, -df1_12_rawFy1, color = 'red')
#plt.plot(-df1_13_rawZ1-0.187, -df1_13_rawFy1, color = 'red')
#plt.plot(-df1_14_rawZ1-0.189, -df1_14_rawFy1, color = 'red')
#plt.plot(-df1_15_rawZ1-0.1885, -df1_15_rawFy1, color = 'red')
#plt.plot(-df1_16_rawZ1-0.189, -df1_16_rawFy1, color = 'red')
#plt.plot(-df1_17_rawZ1-0.204, -df1_17_rawFy1, color = 'red')
#plt.plot(-df1_18_rawZ1-0.205, -df1_18_rawFy1, color = 'red')
#plt.plot(-df1_19_rawZ1-0.198, -df1_19_rawFy1, color = 'red')
#plt.plot(-df1_20_rawZ1-0.203, -df1_20_rawFy1, color = 'red')

#### T2 ####
#plotting
plt.plot(-df2_1_rawZ1-0.193, -df2_1_rawFy1, color = 'b', label = r'$\phi_{min}$')
plt.plot(-df2_2_rawZ1-0.194, -df2_2_rawFy1, color = 'b')
plt.plot(-df2_3_rawZ1-0.207, -df2_3_rawFy1, color = 'b')
plt.plot(-df2_4_rawZ1-0.203, -df2_4_rawFy1, color = 'b')
plt.plot(-df2_5_rawZ1-0.214, -df2_5_rawFy1, color = 'b') #good
plt.plot(-df2_6_rawZ1-0.207, -df2_6_rawFy1, color = 'b')
plt.plot(-df2_7_rawZ1-0.216, -df2_7_rawFy1, color = 'b')
plt.plot(-df2_8_rawZ1-0.20, -df2_8_rawFy1, color = 'b')
plt.plot(-df2_9_rawZ1-0.215, -df2_9_rawFy1, color = 'b')
plt.plot(-df2_10_rawZ1-0.211, -df2_10_rawFy1, color = 'b')
plt.plot(-df2_11_rawZ1-0.206, -df2_11_rawFy1, color = 'b') #good 
plt.plot(-df2_12_rawZ1-0.226, -df2_12_rawFy1, color = 'b')
plt.plot(-df2_13_rawZ1-0.202, -df2_13_rawFy1, color = 'b')
plt.plot(-df2_14_rawZ1-0.209, -df2_14_rawFy1, color = 'b')
plt.plot(-df2_15_rawZ1-0.21, -df2_15_rawFy1, color = 'b')
plt.plot(-df2_16_rawZ1-0.20, -df2_16_rawFy1, color = 'b')
plt.plot(-df2_17_rawZ1-0.209, -df2_17_rawFy1, color = 'b')
plt.plot(-df2_18_rawZ1-0.205, -df2_18_rawFy1, color = 'b')
plt.plot(-df2_19_rawZ1-0.213, -df2_19_rawFy1, color = 'b') #good
plt.plot(-df2_20_rawZ1-0.209, -df2_20_rawFy1, color = 'b')


#### T3 #####
plt.plot(-df3_1_rawZ1-0.193, -df3_1_rawFy1, color = 'white', label = r'$\phi_{max}$')
plt.plot(-df3_2_rawZ1-0.196, -df3_2_rawFy1, color = 'white')
plt.plot(-df3_3_rawZ1-0.195, -df3_3_rawFy1, color = 'white')
plt.plot(-df3_4_rawZ1-0.207, -df3_4_rawFy1, color = 'white')
plt.plot(-df3_5_rawZ1-0.201, -df3_5_rawFy1, color = 'white')
plt.plot(-df3_6_rawZ1-0.198, -df3_6_rawFy1, color = 'white')
plt.plot(-df3_7_rawZ1-0.192, -df3_7_rawFy1, color = 'white')
plt.plot(-df3_8_rawZ1-0.207, -df3_8_rawFy1, color = 'white')
plt.plot(-df3_9_rawZ1-0.205, -df3_9_rawFy1, color = 'white')
plt.plot(-df3_10_rawZ1-0.2025, -df3_10_rawFy1, color = 'white')
plt.plot(-df3_11_rawZ1-0.2065, -df3_11_rawFy1, color = 'white') 
plt.plot(-df3_12_rawZ1-0.2125, -df3_12_rawFy1, color = 'white')
plt.plot(-df3_13_rawZ1-0.212, -df3_13_rawFy1, color = 'white')
plt.plot(-df3_15_rawZ1-0.19, -df3_15_rawFy1, color = 'white')
plt.plot(-df3_16_rawZ1-0.199, -df3_16_rawFy1, color = 'white')
plt.plot(-df3_17_rawZ1-0.2065, -df3_17_rawFy1, color = 'white')
plt.plot(-df3_18_rawZ1-0.1915, -df3_18_rawFy1, color = 'white')
plt.plot(-df3_19_rawZ1-0.20, -df3_19_rawFy1, color = 'white')
plt.plot(-df3_20_rawZ1-0.20, -df3_20_rawFy1, color = 'white')

plt.xlabel("$\it{h}$ (m)", size = 'xx-large')
plt.ylabel(r'$F_{z}$ (N)', size = 'xx-large')
plt.legend(fontsize = 18, frameon = False)
plt.tick_params(axis='both', which='major', labelsize=14)
